# %% [markdown]
# ## Superstore Sales Analysis

# %% [markdown]
# ## Import libraries

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read CSV File

# %%
df = pd.read_csv("/Applications/Coding/Project's/Superstore-Sales-Analysis/data/samplesuperstore.csv")
